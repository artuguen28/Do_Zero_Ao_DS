# %% [markdown]
# #### Exercícios da aula 2

# %% [markdown]
# 1)

# %%
import pandas as pd

# %%
data_ex = pd.read_csv('datasets\kc_house_data.csv')
data_ex['date'] = pd.to_datetime(data_ex['date'])

data_ex['house_age'] = 'house'

data_ex.loc[data_ex['date'] > '2015-01-01', 'house_age'] = 'new_house'
data_ex.loc[data_ex['date'] < '2015-01-01', 'house_age'] = 'old_house'

data_ex.head(50)
# Out:
#             id       date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520 2014-10-13   221900.0         3       1.00         1180
# 1   6414100192 2014-12-09   538000.0         3       2.25         2570
# 2   5631500400 2015-02-25   180000.0         2       1.00          770
# 3   2487200875 2014-12-09   604000.0         4       3.00         1960
# 4   1954400510 2015-02-18   510000.0         3       2.00         1680
# 5   7237550310 2014-05-12  1225000.0         4       4.50         5420
# 6   1321400060 2014-06-27   257500.0         3       2.25         1715
# 7   2008000270 2015-01-15   291850.0         3       1.50         1060
# 8   2414600126 2015-04-15   229500.0         3       1.00         1780
# 9   3793500160 2015-03-12   323000.0         3       2.50         1890
# 10  1736800520 2015-04-03   662500.0         3       2.50         3560
# 11  9212900260 2014-05-27   468000.0         2       1.00         1160
# ...

# %% [markdown]
# 2.

# %%
data_ex['dormitory_type'] = 'house'

data_ex.loc[data_ex['bedrooms'] == 1, 'dormitory_type'] = 'studio'
data_ex.loc[data_ex['bedrooms'] == 2, 'dormitory_type'] = 'apartament'

data_ex.head(50)
# Out:
#             id       date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520 2014-10-13   221900.0         3       1.00         1180
# 1   6414100192 2014-12-09   538000.0         3       2.25         2570
# 2   5631500400 2015-02-25   180000.0         2       1.00          770
# 3   2487200875 2014-12-09   604000.0         4       3.00         1960
# 4   1954400510 2015-02-18   510000.0         3       2.00         1680
# 5   7237550310 2014-05-12  1225000.0         4       4.50         5420
# 6   1321400060 2014-06-27   257500.0         3       2.25         1715
# 7   2008000270 2015-01-15   291850.0         3       1.50         1060
# 8   2414600126 2015-04-15   229500.0         3       1.00         1780
# 9   3793500160 2015-03-12   323000.0         3       2.50         1890
# 10  1736800520 2015-04-03   662500.0         3       2.50         3560
# 11  9212900260 2014-05-27   468000.0         2       1.00         1160
# ...

# %% [markdown]
# 3.

# %%
data_ex['condition_type'] = 'bad'

data_ex.loc[data_ex['condition'] == 3, 'condition_type'] = 'regular'
data_ex.loc[data_ex['condition'] == 4, 'condition_type'] = 'regular'
data_ex.loc[data_ex['condition'] == 5, 'condition_type'] = 'good'

data_ex[['condition','condition_type']].head(50)
# Out:
#     condition condition_type
# 0           3        regular
# 1           3        regular
# 2           3        regular
# 3           5           good
# 4           3        regular
# 5           3        regular
# 6           3        regular
# 7           3        regular
# 8           3        regular
# 9           3        regular
# 10          3        regular
# 11          4        regular
# 12          4        regular
# 13          4        regular
# 14          3        regular
# 15          3        regular
# 16          3        regular
# 17          4        regular
# 18          4        regular
# 19          4        regular
# 20          4        regular
# 21          3        regular
# 22          3        regular
# 23          3        regular
# 24          4        regular
# 25          5           good
# 26          3        regular
# 27          5           good
# 28          3        regular
# 29          3        regular
# 30          3        regular
# ...

# %% [markdown]
# 4.

# %%
data_ex['condition'] = data_ex['condition'].astype(str)

data_ex.dtypes
# Out:
# id                         int64
# date              datetime64[ns]
# price                    float64
# bedrooms                   int64
# bathrooms                float64
# sqft_living                int64
# sqft_lot                   int64
# floors                   float64
# waterfront                 int64
# view                       int64
# condition                 object
# grade                      int64
# sqft_above                 int64
# sqft_basement              int64
# yr_built                   int64
# yr_renovated               int64
# zipcode                    int64
# lat                      float64
# long                     float64
# sqft_living15              int64
# sqft_lot15                 int64
# house_age                 object
# dormitory_type            object
# condition_type            object
# dtype: object

# %% [markdown]
# 5.

# %%
data_ex.drop(['sqft_living15', 'sqft_lot15'], axis=1, inplace=True)

data_ex.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'house_age', 'dormitory_type', 'condition_type'],
#       dtype='object')

# %% [markdown]
# 6. 7.

# %%
data['date'] = pd. v
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-2bb03f59bfda> in <module>
# ----> 1 data['date'] = pd. v
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'v'

# %% [markdown]
# 8.

# %%
data_ex.sort_values('yr_built', ascending=False)

data_ex.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ... sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...       1180              0
# 1      7242     2.0           0     0  ...       2170            400
# 2     10000     1.0           0     0  ...        770              0
# 3      5000     1.0           0     0  ...       1050            910
# 4      8080     1.0           0     0  ...       1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  house_age  \
# 0      1955             0    98178  47.5112 -122.257  old_house
# ...

# %% [markdown]
# 10.

# %%
floors = data_ex.loc[data_ex['floors'] == 2, 'floors']

floors.to_csv('datasets/floors_aula2.csv', index=False)

# %% [markdown]
# 11.

# %%
len(data_ex.loc[(data_ex['condition_type'] == 'good') & (data_ex['house_age'] == 'new_house')])
# Out:
# 423

# %% [markdown]
# 14.

# %%
data_ex.loc[data_ex['dormitory_type'] == 'studio'].sort_values('price', ascending=False).head(6)
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 8445    724069023 2015-04-14  1247000.0         1       1.25         1810
# 9888   1231000310 2014-08-12   713000.0         1       1.00         1180
# 4410   4083304190 2014-08-04   680000.0         1       2.50         1820
# 8165   1797500530 2015-05-05   655100.0         1       1.00         1220
# 19273  9164100035 2015-04-29   655000.0         1       1.00         1660
# 9563   3023039231 2014-07-14   650000.0         1       1.00          920
#
#        sqft_lot  floors  waterfront  view  ... sqft_above  sqft_basement  \
# 8445       5070     1.5           1     4  ...       1230            580
# 9888       4000     1.5           0     2  ...        840            340
# 4410       3008     2.0           0     0  ...       1090            730
# 8165       4160     1.0           0     0  ...       1220              0
# 19273      5422     1.0           0     0  ...        830            830
# ...

# %% [markdown]
# 15.

# %% [markdown]
# 16.

# %%
data_ex.loc[data_ex['dormitory_type'] == 'house'].sort_values('bedrooms', ascending=False)

data_ex.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'house_age', 'dormitory_type', 'condition_type'],
#       dtype='object')

# %% [markdown]
# 17.

# %%
data_ex.loc[:, ['id', 'date', 'price', 'floors', 'zipcode']]

data_ex.iloc[:, [0, 1, 2, 7, 16]]

data_ex.
# Out:
#                id       date     price  floors  zipcode
# 0      7129300520 2014-10-13  221900.0     1.0    98178
# 1      6414100192 2014-12-09  538000.0     2.0    98125
# 2      5631500400 2015-02-25  180000.0     1.0    98028
# 3      2487200875 2014-12-09  604000.0     1.0    98136
# 4      1954400510 2015-02-18  510000.0     1.0    98074
# ...           ...        ...       ...     ...      ...
# 21608   263000018 2014-05-21  360000.0     3.0    98103
# 21609  6600060120 2015-02-23  400000.0     2.0    98146
# 21610  1523300141 2014-06-23  402101.0     2.0    98144
# 21611   291310100 2015-01-16  400000.0     2.0    98027
# 21612  1523300157 2014-10-15  325000.0     2.0    98144
#
# [21613 rows x 5 columns]
